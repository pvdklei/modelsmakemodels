# %% [markdown]
# <a href="https://colab.research.google.com/github/pvdklei/modelsmakemodels/blob/master/pepijn/feature_visuals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import visual_tools as vt
import utils
import importlib
import torchvision
import torch
from torch import nn
import cv2
import torchvision as tv
import torchvision.transforms.functional as FT
import matplotlib.pyplot as plt

# %%
image = vt.read_image("img/cat.jpg")
vt.show_image(image, figsize=(8, 8))

# %%
vgg = torchvision.models.vgg16(pretrained=True).features
len(vgg)
# Out:
# 31

# %%
vt.response_of_features_to_image(image, vgg, -1)
# Out:
# Accessing layer -1: MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# Using device:  cuda
# Largest activations are [5.860447406768799, 2.395167112350464, 2.252932548522949], at [328, 122, 425]

# %%
importlib.reload(vt)
vt.image_that_feature_responds_to_most(vgg, 
                                       -1, 
                                       328, 
                                       (50, 50), 
                                       lr=0.01, 
                                       iters=20, 
                                       upscaling_steps=10,
                                       upscaling_factor=1.2)
# Out:
# Device:  cuda
# This will evaluate the features of channel 328 after layer -1: MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# Done with upscaling step:  0
# Done with upscaling step:  1
# Done with upscaling step:  2
# Done with upscaling step:  3
# Done with upscaling step:  4
# Done with upscaling step:  5
# Done with upscaling step:  6
# Done with upscaling step:  7
# Done with upscaling step:  8
# Done with upscaling step:  9
