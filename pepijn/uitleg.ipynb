# %%
import torch 
import torchvision 
import utils

# %%
model = utils.load_pickle("models/alexnet_autoencoder")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-2ef88e053ed7> in <module>
# ----> 1 model = utils.load_pickle("models/alexnet_autoencoder")
#
# ~/Desktop/LerenBeslissen/modelsmakemodels/pepijn/utils.py in load_pickle(filename)
#       7 def load_pickle(filename):
#       8     with open(filename + '.pkl', 'rb') as f:
# ----> 9         return pickle.load(f)
#      10
#      11 def _conv_out_shape(og_size, filter_size, stride, padding):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/storage.py in _load_from_bytes(b)
#     139
#     140 def _load_from_bytes(b):
# --> 141     return torch.load(io.BytesIO(b))
#     142
#     143
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     593                     return torch.jit.load(opened_file)
# ...
